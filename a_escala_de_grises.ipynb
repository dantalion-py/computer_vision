# %%
import cv2
import matplotlib.pyplot as pls
import numpy as np

# %%
img = np.zeros((10,10,1),np.uint8)

# %% [markdown]
# Creacion de imagenes escala de grises

# %%
img[0,0] = 10
img[1,1] = 20
img[2,2] = 50
img[3,3] = 70
img[4,4] = 80
img[5,5] = 100
img[6,6] = 120
img[7,7] = 140
img[8,8] = 160
img[9,9] = 180
pls.imshow(img,cmap='gray')

# %%
img = 100 * np.ones((10,10,3),np.uint8)
R = img[:,:,0]
R[:,:] = 255
G = img[:,:,1]
G[:,:] = 255
B = img[:,:,2]
B[:,:] = 0
pls.imshow(img,cmap='gray')
