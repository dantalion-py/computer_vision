# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# el atributo 1 es es para RGB y el O para escala de grises y sin atributos por defaut es RGB

# %%
img = cv2.imread('img/tatsumaki.png',0)
imgGray = cv2.imread('img/tatsumaki.png')
imgRGB = cv2.imread('img/tatsumaki.png',1)

# %% [markdown]
# Extraer atributos principales RGB

# %%
imgRGB_type = imgRGB.dtype
imgRGB_tama = imgRGB.shape
print(f"""
imagen de tamaño {imgRGB_tama}
y tipo {imgRGB_type}
""")
# Out:
# imagen de tamaño (1013, 1350, 3)
# y tipo uint8

# %% [markdown]
# Extraer atributos principales escala de grises

# %%
img_type = img.dtype
img_tama = img.shape
print(f"""
imagen de tamaño {img_tama}
y tipo {img_type}
""")
# Out:
# imagen de tamaño (1013, 1350)
# y tipo uint8

# %% [markdown]
# Se debe de cerrar el ciclo de apertura y muestra de la imagen, de lo contrario no se podra mostrar la imagen y sobrecargara el kernel

# %%
# cv2.imshow("GRAY",imgGray)
cv2.imshow("RGB",imgRGB)
# cv2.imshow("IMG",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Para que los colores se muestren en RGB y no en BGR se debe realizar la correccion del color

# %%
imgRGB = cv2.cvtColor(imgRGB, cv2.COLOR_BGR2RGB)
plt.imshow(imgRGB)
# plt.imshow(img)
# plt.imshow(imgGray)
plt.show()
